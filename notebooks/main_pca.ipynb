# %% [markdown]
# ## Imports

# %%
import numpy as np
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parents[0]))

import scripts.prepare as prepare
import scripts.services as services
import scripts.roi as roi_services
import scripts.bss_pipeline as bss_pl
import scripts.visualization as vis

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### fixed variables

# %%
NFRAMES_OUT = 800
SCALE_OUT = 0.2
FPS_OUT = 240
ROIS = roi_services.load_rois(str(Path.cwd().parents[0] / "rois/rois.json"))
PATH_OUT = str(Path.cwd().parents[0] / "outputs")

# %% [markdown]
# ### Inspec one day

# %%
VIDEO_PATH_IN = str(Path.cwd().parents[0] / "videos/camp_2/20260520/20260520_1/m/VID_20260520_072412821.mp4")
VIDEO_NAME = VIDEO_PATH_IN.split("/")[-1]
VIDEO_PATH_OUT = str(Path.cwd().parents[0] / "outputs" / "misc" / VIDEO_NAME)
VIDEO_ROI = ROIS[VIDEO_NAME]

# %%
prepare.pre_processing(VIDEO_PATH_IN, VIDEO_PATH_OUT, NFRAMES_OUT, FPS_OUT, SCALE_OUT, VIDEO_ROI)
video_out_info = services.get_video_info(VIDEO_PATH_OUT)
video_out_info

# %%
dataset = bss_pl.load_grayscale_dataset(VIDEO_PATH_OUT)
H, W, V = bss_pl.compute_pca(dataset)

# %%
n_pc = services.get_num_components_for_variance(V, 90)
n_pc

# %%
vis.plot_pca_eigenvalues_with_threshold(V, 90)

# %% [markdown]
# ### Inspec over time: execute just the cell related to one camp (1, 2 or 3)

# %% [markdown]
# #### camp 1

# %%
# 1 experimento: irrigação no primeiro dia apenas
plant_names_1 = ['../videos/camp_1/20260207/240/VID_20260207_081701560.mp4', 
                 '../videos/camp_1/20260208/240/VID_20260208_071551134.mp4',
                 '../videos/camp_1/20260209/240/VID_20260209_075208490.mp4',
                 '../videos/camp_1/20260210/240/VID_20260210_073714886.mp4',
                 '../videos/camp_1/20260211/240/VID_20260211_072715346.mp4',
                 '../videos/camp_1/20260212/240/VID_20260212_072409310.mp4',
                 '../videos/camp_1/20260213/240/VID_20260213_073426768.mp4',
                 '../videos/camp_1/20260214/240/VID_20260214_040340493.mp4']

# 2 experimento: irrigação diária
# nota sobre o dia 20260402: vídeo removido, pois trocamos de câmera no dia 20260403
plant_names_2 = ['../videos/camp_1/20260403/240/VID_20260403_093930290.mp4',
                 '../videos/camp_1/20260404/240/VID_20260404_083559178.mp4',
                 '../videos/camp_1/20260405/240/VID_20260405_081814881.mp4',
                 '../videos/camp_1/20260406/240/VID_20260406_073657130.mp4',
                 '../videos/camp_1/20260407/240/VID_20260407_072634451.mp4',
                 '../videos/camp_1/20260408/240/VID_20260408_073141468.mp4',
                 '../videos/camp_1/20260409/240/VID_20260409_062613791.mp4',
                 '../videos/camp_1/20260410/240/VID_20260410_072958947.mp4']

# %% [markdown]
# #### camp 2

# %%
# as duas plantas foram irrigadas diariamente
# irrigação pela parte da amanhã apenas, uma vez ao dia
# filmagens de manhã e a noite por dia

plant_names_1 = ['../videos/camp_2/20260520/20260520_1/m/VID_20260520_072412821.mp4',
                 '../videos/camp_2/20260520/20260520_1/n/VID_20260520_221601529.mp4',
                 '../videos/camp_2/20260521/20260521_1/m/VID_20260521_070841873.mp4',
                 '../videos/camp_2/20260521/20260521_1/n/VID_20260521_211614176.mp4',
                 '../videos/camp_3/20260606/20260606_1/m/VID_20260606_073857092.mp4',
                 '../videos/camp_3/20260606/20260606_1/n/VID_20260606_195750977.mp4',
                 '../videos/camp_3/20260607/20260607_1/m/VID_20260607_081304960.mp4',
                 '../videos/camp_3/20260607/20260607_1/n/VID_20260607_183651231.mp4',                 
                ]

plant_names_2 = ['../videos/camp_3/20260525/20260525_2/m/VID_20260525_073831392.mp4',
                 '../videos/camp_3/20260525/20260525_2/n/VID_20260525_185326185.mp4',
                 '../videos/camp_3/20260526/20260526_2/m/VID_20260526_073755265.mp4',
                 '../videos/camp_3/20260526/20260526_2/n/VID_20260526_202842902.mp4',
                 '../videos/camp_3/20260527/20260527_2/m/VID_20260527_074035158.mp4',
                 '../videos/camp_3/20260527/20260527_2/n/VID_20260527_202347776.mp4',
                 '../videos/camp_3/20260528/20260528_2/m/VID_20260528_060627096.mp4',
                 '../videos/camp_3/20260528/20260528_2/n/VID_20260528_194140546.mp4',
                 '../videos/camp_3/20260529/20260529_2/m/VID_20260529_083140178.mp4',
                 '../videos/camp_3/20260529/20260529_2/n/VID_20260529_200501170.mp4',
                 '../videos/camp_3/20260530/20260530_2/m/VID_20260530_074702260.mp4',
                 '../videos/camp_3/20260530/20260530_2/n/VID_20260530_212439482.mp4',
                 '../videos/camp_3/20260531/20260531_2/m/VID_20260531_074018077.mp4',
                 '../videos/camp_3/20260531/20260531_2/n/VID_20260531_205352664.mp4',
                 '../videos/camp_3/20260601/20260601_2/m/VID_20260601_074946932.mp4',
                 '../videos/camp_3/20260601/20260601_2/n/VID_20260602_002637371.mp4',
                 '../videos/camp_3/20260602/20260602_2/m/VID_20260602_082906225.mp4',
                 '../videos/camp_3/20260602/20260602_2/n/VID_20260602_215933123.mp4',
                 '../videos/camp_3/20260603/20260603_2/m/VID_20260603_091456724.mp4',
                 '../videos/camp_3/20260603/20260603_2/n/VID_20260603_202219603.mp4',
                 '../videos/camp_3/20260604/20260604_2/m/VID_20260604_083609177.mp4',
                 '../videos/camp_3/20260604/20260604_2/n/VID_20260604_204649342.mp4',
                 '../videos/camp_3/20260605/20260605_2/m/VID_20260605_085242545.mp4',
                 '../videos/camp_3/20260605/20260605_2/n/VID_20260605_204823754.mp4',
                 '../videos/camp_3/20260606/20260606_2/m/VID_20260606_073814392.mp4',
                 '../videos/camp_3/20260606/20260606_2/n/VID_20260606_195849439.mp4',
                 '../videos/camp_3/20260607/20260607_2/m/VID_20260607_081227742.mp4',
                 '../videos/camp_3/20260607/20260607_2/n/VID_20260607_183615322.mp4',                 
                ]

# %% [markdown]
# #### pre-process the videos: do it just one time

# %%
camp = "camp_1" # choose output directory
for i, video_path_in in enumerate(plant_names_1 + plant_names_1):
    print(f'{video_path_in} processing...', end = ' ')
    video_name = video_path_in.split('/')[-1]
    prepare.pre_processing(video_path_in, PATH_OUT + f"/{camp}/" + video_name, NFRAMES_OUT, FPS_OUT, SCALE_OUT, ROIS[video_name])
    print(f'done.')

# %%
results = []
for video_path_in in plant_names_1 + plant_names_2:
    dataset = bss_pl.load_grayscale_dataset(PATH_OUT + f"/{camp}/" + video_path_in.split('/')[-1])
    H, W, V = bss_pl.compute_pca(dataset)
    results.append(services.get_num_components_for_variance(V, 90))

# %%
print(results)
print(np.mean(results))
